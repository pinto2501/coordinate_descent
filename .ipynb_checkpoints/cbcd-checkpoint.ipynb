# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Initialize

# %%
n = 100
c = 0.35

I = np.identity(n)
L = -np.tril(c * np.ones((n, n)), k=-1) # moves boundary one step below the diagonal
A_c = np.identity(n)- L - L.T
C = np.linalg.inv(I-L) @ L.T
S = np.diag([1/(n) for i in range(n)])
R = np.linalg.matrix_power(I - S @ np.linalg.inv(I) @ A_c, n)

# %%
epochs = 5000
x0 = np.ones((n,1))
x = x0.copy()
x_star = np.zeros((n,1))
ccd_errors = []

for l in range(epochs):
    x = C @ x
    norm = np.linalg.norm(x - x_star)
    if norm < 1e-50:
        print(f"Converges at epoch {l}")
        break
    ratio = norm / np.linalg.norm(x0 - x_star)
    ccd_errors.append(np.log(ratio))

ccd_slope, intercept = np.polyfit(range(len(ccd_errors)), ccd_errors, 1)
rho_ccd = np.max(np.abs(np.linalg.eigvals(C)))
rate_ccd = -np.log(rho_ccd)
print(-ccd_slope, rate_ccd)
plt.plot(ccd_errors)
plt.title(f"CCD (n={n}, c={c})")
# Out:
# 0.009819459507909054 0.009816895544071728
# Text(0.5, 1.0, 'CCD (n=100, c=0.35)')

# %%
epochs = 5000
x0 = np.ones((n,1))
x = x0.copy()
x_star = np.zeros((n,1))
rcd_errors = []

for l in range(epochs):
    x = R @ x
    norm = np.linalg.norm(x - x_star)
    if norm < 1e-50:
        print(f"Converges at epoch {l}")
        break
    ratio = norm / np.linalg.norm(x0 - x_star)
    rcd_errors.append(np.log(ratio))


ercd_slope, intercept = np.polyfit(range(len(rcd_errors)), rcd_errors, 1)
rho_ercd = np.max(np.abs(np.linalg.eigvals(R)))
rate_ercd = -np.log(rho_ercd)
print(-ercd_slope, rate_ercd)
plt.plot(rcd_errors)
plt.title(f"ERCD (n={n}, c={c})")
# Out:
# Converges at epoch 129
# 0.652124776939775 0.6521216990263945
# Text(0.5, 1.0, 'ERCD (n=100, c=0.35)')

# %%
def build_coordinate_matrices(n, c):
    mats = []
    for i in range(n):
        M = np.eye(n)
        M[i, i] = 0.0
        M[i, :] = -c  
        M[i, i] = 0.0  
        mats.append(M)
    return mats

mats = build_coordinate_matrices(n, c)

# check if mats is correct

for mat in mats:
    mul_mat = np.matmul(mat, mat)
    if np.array_equal(mat @ mat, mat):
        pass
    else:
        print("Error")

epochs = 5000
x0 = np.ones((n, 1))
x = x0.copy()
x_star = np.zeros((n, 1))
prcd_errors = []

for l in range(epochs):
    for i in range(n): 
        i = random.randint(0, n - 1)
        x = mats[i] @ x
    norm = np.linalg.norm(x - x_star)
    if norm < 1e-50:
        print(f"Converges at iteration {l}")
        break
    else:
        ratio = norm / np.linalg.norm(x0 - x_star)
        prcd_errors.append(np.log(ratio))

# note: This is rate per single coordinate. We run n * epochs to compare with ERCD and CCD which is full epoch.
prcd_slope, intercept = np.polyfit(range(len(prcd_errors)), prcd_errors, 1)
print(-prcd_slope)
plt.plot(prcd_errors)
plt.title(f"PRCD (n={n}, c={c})")
plt.xlabel("Iteration")
plt.ylabel("Log ratio")
# Out:
# Converges at iteration 269
# 0.4487311063437929
# Text(0, 0.5, 'Log ratio')

# %%
print(-prcd_slope, -ccd_slope, -ercd_slope)
# Out:
# 0.4487311063437929 0.009819459507909054 0.652124776939775
